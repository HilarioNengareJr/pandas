# %%
import pandas as panda

# %%
df = panda.read_csv('survey_results_public.csv')
schema_df = panda.read_csv('survey_results_schema.csv')

# %%
df

schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
# a salary filter for salaries above 40000
high_salary = (df['ConvertedCompYearly']>40000)

# %%
df.loc[high_salary,['Country','ConvertedCompYearly', 'Currency']]
# Out:
#                                                  Country  ConvertedCompYearly  \
# 2      United Kingdom of Great Britain and Northern I...              40205.0
# 3                                                 Israel             215232.0
# 8                                            Netherlands              49056.0
# 10     United Kingdom of Great Britain and Northern I...              60307.0
# 11                              United States of America             194400.0
# ...                                                  ...                  ...
# 73114                                            Germany              41058.0
# 73116                           United States of America             115000.0
# 73118                                            Nigeria              57720.0
# 73119                           United States of America              70000.0
# 73121  United Kingdom of Great Britain and Northern I...              75384.0
#
#                         Currency
# ...

# %%
# locate people in this list of countries
countries=['Germany', 'India', 'South Africa']
filt = df['Country'].isin(countries)

# %%
df[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 5               6  I am not primarily a developer, but I write co...
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 25             26                     I am a developer by profession
# 48             49                     I am a developer by profession
# ...           ...                                                ...
# 73247       73248                        I code primarily as a hobby
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
# 73262       73263                              I am learning to code
#
#                                    Employment  \
# 5                          Student, full-time
# ...
